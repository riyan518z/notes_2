# %% [markdown]
# <a href="https://colab.research.google.com/github/riyan518z/notes_2/blob/main/sound_alert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import time
from IPython.display import Audio , display
url="https://raw.githubusercontent.com/velicki/Weather_Data_Analysis_Project/main/Weather_Data.csv"
wdf = pd.read_csv(url)

wdf
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
wdf.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
wdf.columns = wdf.columns.str.strip().str.replace(' ','_').str.replace('/','_')
wdf.columns
# Out:
# Index(['Date_Time', 'Temp_C', 'Dew_Point_Temp_C', 'Rel_Hum_%',
#        'Wind_Speed_km_h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
wdf['Date_Time'] = pd.to_datetime(wdf['Date_Time'])
wdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date_Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew_Point_Temp_C  8784 non-null   float64
#  3   Rel_Hum_%         8784 non-null   int64
#  4   Wind_Speed_km_h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
wdf.isna().sum()
# Out:
# Date_Time           0
# Temp_C              0
# Dew_Point_Temp_C    0
# Rel_Hum_%           0
# Wind_Speed_km_h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
def alert_high_temp(row):
  if(row['Temp_C'] > 3):
    print(f'Alert !!! temp too high : {row['Temp_C']} celsius')
    display(Audio('/content/iPhone Notification Sound.mp3',autoplay=True))
    return True
  else:
    print(f"temp is normal : {row['Temp_C']} celsius")
    return False



def stream_with_alert(data,delay=1):
  for index,row in data.iterrows():
    print(f"{row['Date_Time']} - Temperature : {row['Temp_C']} Celsius")
    if alert_high_temp(row):
      print("help temp alert triggered . stopping streamprocessing")
      break
    time.sleep(delay)


stream_with_alert(wdf)
# Out:
# 2012-01-01 00:00:00 - Temperature : -1.8 Celsius
# temp is normal : -1.8 celsius
# 2012-01-01 01:00:00 - Temperature : -1.8 Celsius
# temp is normal : -1.8 celsius
# 2012-01-01 02:00:00 - Temperature : -1.8 Celsius
# temp is normal : -1.8 celsius
# 2012-01-01 03:00:00 - Temperature : -1.5 Celsius
# temp is normal : -1.5 celsius
# 2012-01-01 04:00:00 - Temperature : -1.5 Celsius
# temp is normal : -1.5 celsius
# 2012-01-01 05:00:00 - Temperature : -1.4 Celsius
# temp is normal : -1.4 celsius
# 2012-01-01 06:00:00 - Temperature : -1.5 Celsius
# temp is normal : -1.5 celsius
# 2012-01-01 07:00:00 - Temperature : -1.4 Celsius
# temp is normal : -1.4 celsius
# 2012-01-01 08:00:00 - Temperature : -1.4 Celsius
# temp is normal : -1.4 celsius
# 2012-01-01 09:00:00 - Temperature : -1.3 Celsius
# temp is normal : -1.3 celsius
# 2012-01-01 10:00:00 - Temperature : -1.0 Celsius
# temp is normal : -1.0 celsius
# 2012-01-01 11:00:00 - Temperature : -0.5 Celsius
# temp is normal : -0.5 celsius
# ...
